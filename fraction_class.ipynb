# %% [markdown]
# <a href="https://colab.research.google.com/github/alimohamad2448-pixel/cs417-exercises/blob/main/fraction_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import gcd
class Fraction:
  def __init__(self, top, bottom):
    self.num = top
    self.den = bottom

  def __str__ (self):
    return f"{self.num}/{self.den}"

  def _reduce(self) :

    common_divisor = gcd(abs(self.num), abs(self.den))
    self.num //= common_divisor
    self.den //= common_divisor

    return self
  def __add__(self, other):

    new_num = self.num * other.den + self.den * other.num
    new_den = self.den * other.den
    result = Fraction(new_num, new_den)
    return result._reduce()

  def __sub__(self, other):

    new_num = self.num * other.den - self.den * other.num
    new_den = self.den * other.den
    result = Fraction(new_num, new_den)
    return result._reduce()

  def __mul__(self, other):

    new_num = self.num * other.num
    new_den = self.den * other.den
    result = Fraction(new_num, new_den)

    return result._reduce()

  def __truediv__(self, other):

    new_num = self.num * other.den
    new_den = self.den * other.num
    result = Fraction(new_num, new_den)

    return result._reduce()

# %%
f1 = Fraction(3,5)
f2 = Fraction(1,2)

# %%
f1 + f2

# %%
f1 - f2

# %% [markdown]
# I'm not sure if you wanted the output to be an actual fraction but since the directions state to just display the result i'll keep it as is.
